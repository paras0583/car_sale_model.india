# %% [markdown]
# 1. WE HAVE DATA OF CAR RESAIL MARKET IN INDIA WE GONNA PERFORM ESPLORATORY DATA ANALYSIS. WE WILL DEVIDE THIS MODULE INTO 3 PARTS 1. PART WILL BE ABOUT DATA LOADING INFORMATION LIKE DATA TYPE AND NO OF COLUMNS. 2 PART WILL BE OF PRESENTATION AND RELATION AND DEPENDENCIESE AND ALL THE STATS OF THE DATA. 3. IN 3RD WE WILL BE DOING PLOTTINGS.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# 1.1 LODAING THE DATA FROM THE KAGGLE CAR SALE MARKET INDIA❤️❤️

# %%
df = pd.read_csv("Car Sell Dataset.csv")

# %% [markdown]
# 1.2 DATA LOADED SUCESSFULLY NOW CHECKING THE NUMBER OF ROWS AND COLUMNS

# %%
df.head(4)
# Out:
#            Brand Model Name Model Variant   Car Type Transmission Fuel Type  \
# 0       Mahindra     TUV300           AX5        SUV       Manual       CNG
# 1          Skoda      Rapid         Style      Sedan       Manual    Petrol
# 2  Maruti Suzuki       Alto             Z  Hatchback       Manual    Diesel
# 3        Hyundai  Grand i10         Magna  Hatchback       Manual    Diesel
#
#    Year  Kilometers Owner           State Accidental   Price
# 0  2017      164654   1st       Rajasthan         No  547253
# 1  2018       41351   1st     Maharashtra         No  512050
# 2  2002      119090  3rd+      Tamil Nadu         No  678923
# 3  2013       19979   1st  Andhra Pradesh         No  522500

# %%
df.shape
# Out:
# (140904, 12)

# %% [markdown]
# 1.3 WE HAVE 140904 ROWS AND FOR EACH ROW OR EACH ENTRY WE HAVE 12 COLUMNS🤔

# %%
column_name=df.columns
print(column_name)
# Out:
# Index(['Brand', 'Model Name', 'Model Variant', 'Car Type', 'Transmission',
#        'Fuel Type', 'Year', 'Kilometers', 'Owner', 'State', 'Accidental',
#        'Price'],
#       dtype='object')

# %% [markdown]
# NAME MENTIONED ABOVE ARE THE NAME OF COLUMNS 😎😎😎

# %% [markdown]
# 1.THIS IS THE INFORMATION ABOUT THE DATA TYPE AND MEMEORY.🌚🌚🌚

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140904 entries, 0 to 140903
# Data columns (total 12 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Brand          140904 non-null  object
#  1   Model Name     140904 non-null  object
#  2   Model Variant  140904 non-null  object
#  3   Car Type       140904 non-null  object
#  4   Transmission   140904 non-null  object
#  5   Fuel Type      140904 non-null  object
#  6   Year           140904 non-null  int64
#  7   Kilometers     140904 non-null  int64
#  8   Owner          140904 non-null  object
#  9   State          140904 non-null  object
#  10  Accidental     140904 non-null  object
#  11  Price          140904 non-null  int64
# dtypes: int64(3), object(9)
# memory usage: 12.9+ MB

# %% [markdown]
# 2. NO OF VALUES IN EACH COLUMNS. WE CAN SEE THERE IS NO NULL VALUES IN WHOLE DATA.

# %%
df.isna().sum()
# Out:
# Brand            0
# Model Name       0
# Model Variant    0
# Car Type         0
# Transmission     0
# Fuel Type        0
# Year             0
# Kilometers       0
# Owner            0
# State            0
# Accidental       0
# Price            0
# dtype: int64

# %% [markdown]
# 2.1 TOTAL NUMBER OF UNIQUE VALUES IN EACH COLUMNS.

# %%
df.nunique()
# Out:
# Brand               18
# Model Name          84
# Model Variant       82
# Car Type             5
# Transmission         2
# Fuel Type            5
# Year                24
# Kilometers       95860
# Owner                3
# State               27
# Accidental           2
# Price            17745
# dtype: int64

# %% [markdown]
# 2.2 DESCRIBING THE STATISTICS OF DATA

# %%
df.describe()
# Out:
#                 Year     Kilometers         Price
# count  140904.000000  140904.000000  1.409040e+05
# mean     2016.960391   95024.595987  7.617872e+05
# std         5.106106   49133.157878  4.438578e+05
# min      2000.000000   10000.000000  5.005500e+04
# 25%      2014.000000   52421.000000  4.116420e+05
# 50%      2018.000000   94973.500000  6.828030e+05
# 75%      2021.000000  137618.000000  1.034178e+06
# max      2023.000000  179998.000000  2.744280e+06

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
Brand_Labels = df['Brand'].value_counts()
print(Brand_Labels)
# Out:
# Brand
# Maruti Suzuki    54030
# Hyundai          22090
# Honda            11936
# Toyota           10483
# Mahindra          9618
# Tata              8825
# Ford              5217
# Volkswagen        3716
# Renault           3024
# Nissan            2184
# Kia               2146
# Skoda             1537
# MG                1492
# BMW               1052
# Audi              1012
# Range Rover        906
# Jaguar             884
# Chevrolet          752
# Name: count, dtype: int64

# %% [markdown]
# 3. PLOTTING GRAPHS AND USEFULL INSIGHTS WE CAN SEE MARUTI SUZUKI VARIABLE HAS THE MOST COUNTS OF CARS.

# %%
plt.figure(figsize=(10,5))
sns.histplot(data=df,x='Brand',kde =True )
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 3.2 PLOTTING THE PIE CHART FOR COLUMN BRAND.😤😤😤

# %%
colors=['red','yellow','blue','green','grey']
labels = Brand_Labels.index
plt.figure(figsize=(15,15))
plt.pie(Brand_Labels,labels=labels,colors=colors)
plt.tight_layout()
plt.title('PIE CHART', fontsize=20)
plt.show()

# %% [markdown]
# 3.3 NOW I DID FOR BRANCH BUT ABOUT OTHER CATEGORICAL COULMNS 😤🤔.WE DID PIE CHART FOR BRAND NOW WE WILL DO FOR COLUMN 'CAR TYPE 'FUEL TYPE ' STATE OF REGISTRATION '.

# %%
df.head(2)
# Out:
#       Brand Model Name Model Variant Car Type Transmission Fuel Type  Year  \
# 0  Mahindra     TUV300           AX5      SUV       Manual       CNG  2017
# 1     Skoda      Rapid         Style    Sedan       Manual    Petrol  2018
#
#    Kilometers Owner        State Accidental   Price
# 0      164654   1st    Rajasthan         No  547253
# 1       41351   1st  Maharashtra         No  512050

# %%
fig , axs = plt.subplots(1,3, figsize=(15,4))
car_type_data = df['Car Type'].value_counts()
labels = car_type_data.index
axs[0].pie(car_type_data , labels = labels, colors=['red' , 'yellow' , 'blue' , 'green'], autopct='%1.1f%%')
plt.tight_layout()
axs[0].set_title("CAR TYPE", fontsize = 10)


Transmission_data = df['Transmission'].value_counts()
labels = Transmission_data.index
axs[1].pie(Transmission_data , labels = labels, colors=['red' , 'yellow' , 'blue' , 'green'], autopct='%1.1f%%')
plt.tight_layout()
axs[1].set_title("Transmission", fontsize = 10)


Fuel_data = df['Fuel Type'].value_counts()
labels = Fuel_data.index
axs[2].pie(Fuel_data , labels = labels, colors=['red' , 'yellow' , 'blue' , 'green'], autopct='%1.1f%%')
plt.tight_layout()
axs[2].set_title("Fuel", fontsize = 10)
plt.show()

# %% [markdown]
# 3.5 WE CAN DRAW SEVERAL CONCLUSION :

# %% [markdown]
# 1. FOR CAR TYPE WE HAVE HATCHBACK WITH THE HIGEST AVAILABILITY FOLLOWED BY SEDAN AND SUV MPV AND THEN LUXURY WITH SMALL PERCENTAGE
#
# 2. WE HAVE DOMINATELY MANUALCARS HOLDING 85 PERCENTAGE AND AUTOMATIC WITH 15.
#
# 3. WE HAVE PETROL CARS WITH ~ 56% FOLLDOWED BY DIESEL AND THEN CNG.

# %% [markdown]
# 3.6 NOW WE CAN ALSO COMPARE ACCIDENT WITH CAR BRAND 💀(I KNOW WHO GONNA TOP THIS LIST ALREADY SUZ...)

# %%
accidental_brand = df[['Accidental', 'Brand']].copy()

# Add 3rd column with count of each Accidental type
accidental_brand['Accident Count'] = accidental_brand['Accidental'].map(df['Accidental'].value_counts())

# Filter only 'Yes' rows
yes_data = accidental_brand[accidental_brand['Accidental'].str.strip().str.lower() == 'yes']

print(yes_data.head())
# Out:
#    Accidental          Brand  Accident Count
# 27        Yes         Toyota           11265
# 45        Yes         Toyota           11265
# 65        Yes  Maruti Suzuki           11265
# 66        Yes  Maruti Suzuki           11265
# 75        Yes  Maruti Suzuki           11265

# %%
df.shape
# Out:
# (140904, 12)

# %% [markdown]
# 3.7 DRAWING A PIECHAR FOR VISUALISATION WHICH BRAND OF CARS HOLD THE MOST NO OF ACCIDENTS TITLE ALTHOUGH I KNOW WHO GONNA TOP THE LIST AT LEAST FOR NOW 💀💀

# %%
# Step 1: Filter only 'Yes' accidental cars
acc_yes = df[df['Accidental'].str.strip().str.lower() == 'yes']

# Step 2: Count of 'Yes' accidents brand-wise
brand_accident_counts = acc_yes['Brand'].value_counts()

# Step 3: Plot pie chart
plt.figure(figsize=(10, 10))
plt.pie(
    brand_accident_counts,
    labels=brand_accident_counts.index,
    autopct='%1.1f%%',
    startangle=140
)
plt.title("Accidental Cars by Brand")
plt.axis('equal')  # For perfect circle
plt.tight_layout()
plt.show()

# %% [markdown]
# CONCLUSION : MARUTI SUZUKI CARS ARE MORE ACCIDNET PRONE WE CAN SEE FOLLOWED HYUNDAI THEN HONDA THEN TOYATA MAHINDRA TATA AND ETC.

# %%
df.head(2)
# Out:
#       Brand Model Name Model Variant Car Type Transmission Fuel Type  Year  \
# 0  Mahindra     TUV300           AX5      SUV       Manual       CNG  2017
# 1     Skoda      Rapid         Style    Sedan       Manual    Petrol  2018
#
#    Kilometers Owner        State Accidental   Price
# 0      164654   1st    Rajasthan         No  547253
# 1       41351   1st  Maharashtra         No  512050

# %% [markdown]
# 3.8 NOW PLOTTING THE BOX AND VIOLEN PLOT TO GET THE 5 SUMMARY OF OUR DATA THIS WILL BE END OF VISUALISATION.

# %%
plt.figure(figsize=(10,10))
plt.title("car brand")
sns.violinplot(x='Brand',data=df,color='violet',linewidth=3)
plt.tight_layout()
plt.xticks(rotation=40)
plt.show()

# %% [markdown]
# 3.9 WE HAVE SOME CATEGORICAL AND NUMERICAL COLUMN AS WE CAN SEE WHERE KILOMETERS AND PRICE ARE THE NUMERICAL COLUMN AND MODEL IS STRING OR RANDOM REST OF THE COLUMN ARE CATEGORICAL. WHAT NEXT 🤔🤔🤔
#
# WELL WE CAN CALCULATE THE PRICE OF THE CAR ON THE BASIS OF BRAND NO OF OWNERS ETC. DATA IS BEST FOR REGRESSION MODEL 🚗🚗🚗🚗🚗🚗.

# %% [markdown]
# 3.10 EDA DONE
